# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_excel('var_dict.xlsx')
columns = ['ORD','TIPO','TAM','OBSERVAÇÃO', 'DESCRIÇÃO DAS CATEGORIAS']
df2 = df.drop(columns, inplace= True, axis=1)
df
# Out:
#                   NOME DA VARIÁVEL  \
# 0                              NaN
# 1                     NU_ANO_CENSO
# 2                           CO_IES
# 3      TP_CATEGORIA_ADMINISTRATIVA
# 4         TP_ORGANIZACAO_ACADEMICA
# ..                             ...
# 101                  IN_CONCLUINTE
# 102              IN_INGRESSO_TOTAL
# 103          IN_INGRESSO_VAGA_NOVA
# 104  IN_INGRESSO_PROCESSO_SELETIVO
# 105                NU_ANO_INGRESSO
#
#                                  DESCRIÇÃO DA VARIÁVEL
# 0                                                  NaN
# 1                  Ano de referência do Censo Superior
# 2                 Código único de identificação da IES
# 3              Tipo da Categoria Administrativa da IES
# 4                 Tipo da Organização Acadêmica da IES
# ..                                                 ...
# 101                    Informa se o aluno é concluinte
# 102  Informa se o aluno é ingressante no curso, não...
# ...

# %%
df['ds_var'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
cols = df.select_dtypes(include=[np.object]).columns
df[cols] = df[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
df.set_index('nm_var').T.to_dict('dict')
df
# Out:
# C:\Users\olivc\AppData\Local\Temp/ipykernel_23964/3151801047.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cols = df.select_dtypes(include=[np.object]).columns
#                             nm_var  \
# 0                              nan
# 1                     NU_ANO_CENSO
# 2                           CO_IES
# 3      TP_CATEGORIA_ADMINISTRATIVA
# 4         TP_ORGANIZACAO_ACADEMICA
# ..                             ...
# 101                  IN_CONCLUINTE
# 102              IN_INGRESSO_TOTAL
# 103          IN_INGRESSO_VAGA_NOVA
# 104  IN_INGRESSO_PROCESSO_SELETIVO
# 105                NU_ANO_INGRESSO
#
#                                                 ds_var
# 0                                                  NaN
# ...

# %%
data = df.to_json(orient='index')
data
# Out:
# '{"0":{"nm_var":"nan","ds_var":null},"1":{"nm_var":"NU_ANO_CENSO","ds_var":"Ano de referencia do Censo Superior"},"2":{"nm_var":"CO_IES","ds_var":"Codigo unico de identificacao da IES"},"3":{"nm_var":"TP_CATEGORIA_ADMINISTRATIVA","ds_var":"Tipo da Categoria Administrativa da IES"},"4":{"nm_var":"TP_ORGANIZACAO_ACADEMICA","ds_var":"Tipo da Organizacao Academica da IES"},"5":{"nm_var":"CO_CURSO","ds_var":"Codigo unico de identificacao do curso gerado pelo E-MEC"},"6":{"nm_var":"CO_CURSO_POLO","ds_var":"Codigo de identificacao do polo vinculado ao curso"},"7":{"nm_var":"TP_TURNO","ds_var":"Tipo do turno do curso ao qual o aluno esta vinculado"},"8":{"nm_var":"TP_GRAU_ACADEMICO","ds_var":"Tipo do grau academico conferido ao diplomado pelo curso"},"9":{"nm_var":"TP_MODALIDADE_ENSINO","ds_var":"Tipo da modalidade de ensino do curso"},"10":{"nm_var":"TP_NIVEL_ACADEMICO","ds_var":"Tipo do nivel academico do curso"},"11":{"nm_var":"CO_CINE_ROTULO","ds_var":"Codigo de identificacao do curso, a
# ...

# %%
df.to_dict('records')
# Out:
# [{'nm_var': 'nan', 'ds_var': nan},
#  {'nm_var': 'NU_ANO_CENSO', 'ds_var': 'Ano de referencia do Censo Superior'},
#  {'nm_var': 'CO_IES', 'ds_var': 'Codigo unico de identificacao da IES'},
#  {'nm_var': 'TP_CATEGORIA_ADMINISTRATIVA',
#   'ds_var': 'Tipo da Categoria Administrativa da IES'},
#  {'nm_var': 'TP_ORGANIZACAO_ACADEMICA',
#   'ds_var': 'Tipo da Organizacao Academica da IES'},
#  {'nm_var': 'CO_CURSO',
#   'ds_var': 'Codigo unico de identificacao do curso gerado pelo E-MEC'},
#  {'nm_var': 'CO_CURSO_POLO',
#   'ds_var': 'Codigo de identificacao do polo vinculado ao curso'},
#  {'nm_var': 'TP_TURNO',
#   'ds_var': 'Tipo do turno do curso ao qual o aluno esta vinculado'},
#  {'nm_var': 'TP_GRAU_ACADEMICO',
#   'ds_var': 'Tipo do grau academico conferido ao diplomado pelo curso'},
#  {'nm_var': 'TP_MODALIDADE_ENSINO',
#   'ds_var': 'Tipo da modalidade de ensino do curso'},
#  {'nm_var': 'TP_NIVEL_ACADEMICO',
#   'ds_var': 'Tipo do nivel academico do curso'},
# ...
